# %%
from gptTest import run_visEval
key = "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"

# %%
run_visEval('4033', 0, key)
# Out:
# 4033 - 0:
# From 1973 to 1979, show the maximum acceleration of cars with 4, 6, and 8 cylinders each year. Line chart.
#
# Database = car_1;   chosen_table = cars_data
#
#
# import pandas as pd
# import matplotlib.pyplot as plt
#
# df = pd.read_csv('./visEval_dataset/databases/car_1/cars_data.csv')
#
# filtered_df = df[(df['Year'] >= 1973) & (df['Year'] <= 1979)]
# max_acceleration = filtered_df.groupby(['Year', 'Cylinders'])['Accelerate'].max().unstack()
#
# fig, ax = plt.subplots(1, 1, figsize=(10, 4))
# ax.spines['top'].set_visible(False)
# ax.spines['right'].set_visible(False)
#
# max_acceleration.plot(ax=ax)
#
# ax.set_xlabel('Year')
# ax.set_ylabel('Max Acceleration')
# ax.set_title('Maximum Acceleration by Year for Cars with 4, 6, and 8 Cylinders')
# fig.suptitle('{}')
#
# plt.show()
